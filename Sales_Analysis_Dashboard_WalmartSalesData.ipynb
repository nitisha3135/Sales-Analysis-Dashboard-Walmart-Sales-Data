# %% [markdown]
# # 🔖 Sales Analysis Dashboard – Walmart Sales Data

# %% [markdown]
# ## 📖 Project Description
# This project aims to analyze Walmart's retail sales data to uncover key insights, identify trends, and forecast future sales. Using **Python, Pandas, Matplotlib, and Power BI/Tableau**, we process and visualize the dataset to make data-driven business decisions. The project covers sales performance analysis, holiday impact, economic factors, and forecasting.

# %% [markdown]
# -----

# %% [markdown]
# ## 📑 Table of Contents
# <div style="background-color:#e7f3fe; padding:10px; border-left:5px solid #2196F3;">
#     <ul>
#         <li><strong>Introduction</strong>
#             <ul>
#                 <li>Project Overview</li>
#                 <li>Objectives</li>
#             </ul>
#         </li>
#         <li><strong>Dataset Overview</strong>
#             <ul>
#                 <li>Data Source</li>
#                 <li>Description of Columns</li>
#             </ul>
#         </li>
#         <li><strong>Steps to Build the Project</strong>
#             <ul>
#                 <li>Step 1: Load the Dataset</li>
#                 <li>Step 2: Convert Data Types</li>
#                 <li>Step 3: Sales Trend Over Time</li>
#                 <li>Step 4: Sales Impact During Holidays</li>
#                 <li>Step 5: Store-Wise Sales Performance</li>
#                 <li>Step 6: Correlation Analysis</li>
#                 <li>Step 7: Predict Future Sales Using Linear Regression</li>
#             </ul>
#         </li>
#         <li><strong>Key Insights</strong></li>
#         <li><strong>Conclusion</strong></li>
#     </ul>
# </div>

# %% [markdown]
# -----

# %% [markdown]
# ## 🛠️ Technologies Used
# <div style="background-color:#e7f3fe; padding:10px; border-left:5px solid #2196F3;">
#     <ul>
#         <li><b>Python Libraries:** Pandas, Matplotlib, Seaborn, Scikit-learn </li>
#         <li><b>Data Processing:** Pandas, NumPy </li>
#         <li><b>Visualization:** Matplotlib, Seaborn </li>
#         <li><b>Machine Learning:** Linear Regression (Scikit-learn) </li>
#     </ul>
# </div>

# %% [markdown]
# -----

# %% [markdown]
# ## 📝 Steps to Build the Project

# %% [markdown]
# ### 🔹 Step 1: Load the Dataset

# %% [markdown]
# First, let's load the dataset and check for missing values.

# %%
import pandas as pd

# Load dataset
df = pd.read_csv(r"D:\Data Analytics Projects\Project 1\archive\Walmart.csv")

# Display the first few rows
print(df.head())

# Check for missing values
print(df.isnull().sum())
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %% [markdown]
# -----

# %% [markdown]
# ### 🔹 Step 2: Convert Data Types

# %% [markdown]
# We need to ensure the Date column is in datetime format.

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%d-%m-%Y")

# %% [markdown]
# -----

# %% [markdown]
# ### 🔹 Step 3: Sales Trend Over Time

# %% [markdown]
# We will visualize the total sales over time.

# %%
import matplotlib.pyplot as plt

# Group sales by Date
sales_trend = df.groupby("Date")["Weekly_Sales"].sum()

# Plot sales trend
plt.figure(figsize=(12, 6))
plt.plot(sales_trend.index, sales_trend.values, marker="o", linestyle="-")
plt.title("Sales Trend Over Time")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# ### 🔹 Step 4: Sales Impact During Holidays

# %% [markdown]
# Let's analyze whether holidays impact sales.

# %%
import seaborn as sns

# Boxplot of sales on holiday vs non-holiday weeks
plt.figure(figsize=(8, 6))
sns.boxplot(x="Holiday_Flag", y="Weekly_Sales", data=df)
plt.xticks([0, 1], ["Non-Holiday", "Holiday"])
plt.title("Sales Distribution: Holiday vs Non-Holiday")
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# ### 🔹 Step 5: Store-Wise Sales Performance

# %% [markdown]
# Identify top-performing stores.

# %%
# Group by store and sum sales
store_sales = df.groupby("Store")["Weekly_Sales"].sum().sort_values(ascending=False)

# Bar plot of top 10 stores
plt.figure(figsize=(10, 6))
store_sales.head(10).plot(kind="bar", color="blue")
plt.title("Top 10 Best-Performing Stores")
plt.xlabel("Store")
plt.ylabel("Total Sales")
plt.show()

# %% [markdown]
# ------

# %% [markdown]
# ### 🔹 Step 6: Correlation Analysis

# %% [markdown]
# Find correlations between sales and economic factors.

# %%
# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ------

# %% [markdown]
# ### 🔹 Step 7: Predict Future Sales Using Linear Regression

# %% [markdown]
# We'll build a simple regression model.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# Selecting features and target
features = ["Temperature", "Fuel_Price", "CPI", "Unemployment"]
target = "Weekly_Sales"

# Split data
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.2, random_state=42)

# Train model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Evaluate
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error: {mae:.2f}")
# Out:
# Mean Absolute Error: 475178.08

# %% [markdown]
# -----

# %% [markdown]
# ## 📢 Key Insights & Business Recommendations
# <div style="background-color:#e7f3fe; padding:10px; border-left:5px solid #2196F3;">
#     <ul>
#         <li>Trend Analysis: Sales peak during certain months, indicating seasonal effects.</li>
#         <li>Store Performance: Some stores consistently outperform others.</li>
#         <li>Economic Impact: CPI and fuel prices have some correlation with sales.</li>
#         <li>Holiday Effect: Holiday weeks show spikes in sales.</li>
#     </ul>
# </div>

# %% [markdown]
# ## 📌 Conclusion
# This project successfully analyzes Walmart’s sales data using Python, providing key insights on trends, store-wise performance, and the impact of holidays and economic factors. These insights help businesses optimize their sales strategies.

# %% [markdown]
# # Author

# %% [markdown]
# ### Nitisha Nikhare
